# %%
import argparse
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
m = nn.Dropout(p=0.2)
input = torch.randn(20, 16)

# %%
print(input)
# Out:
# tensor([[-1.7029e+00,  9.2062e-02, -5.5281e-01,  2.9380e-01,  3.4965e-01,
#           1.6612e+00,  6.1804e-01,  4.6183e-01,  7.5926e-01, -6.0407e-01,
#          -1.5344e+00,  3.6948e-01, -4.4736e-01, -1.3014e+00, -1.7453e-01,
#          -3.2235e-01],
#         [ 6.3057e-01, -1.0076e+00, -1.5741e+00,  6.8580e-01,  2.0510e-01,
#          -9.4835e-01,  3.3435e-01, -5.2897e-02,  2.0881e-01,  7.3459e-01,
#           7.0361e-02, -3.0032e-01,  3.0774e-01, -2.6769e-01,  1.7486e+00,
#          -6.6110e-01],
#         [ 5.1224e-01,  1.2925e+00,  1.8299e-01,  6.1849e-01,  1.1606e+00,
#          -1.8032e+00, -3.7199e-01,  1.0256e+00, -8.5012e-01, -4.4098e-02,
#           9.4975e-01, -1.2515e+00, -4.1265e-01,  1.0748e+00, -8.5760e-01,
#          -9.8306e-01],
#         [-8.9217e-01,  6.5967e-01,  1.8860e-01, -2.6545e-01, -7.4765e-01,
#           5.1159e-01, -3.2421e-01, -6.8713e-01, -8.1838e-01, -9.4672e-01,
#          -6.4134e-01,  2.6633e+00,  4.8837e-02, -1.0711e+00,  5.9850e-01,
# ...

# %%
output = m(input)

# %%
print(output)
# Out:
# tensor([[-2.1286e+00,  1.1508e-01, -6.9101e-01,  3.6725e-01,  4.3706e-01,
#           2.0765e+00,  7.7255e-01,  5.7729e-01,  9.4907e-01, -7.5509e-01,
#          -1.9181e+00,  0.0000e+00, -5.5920e-01, -0.0000e+00, -2.1816e-01,
#          -0.0000e+00],
#         [ 7.8821e-01, -1.2595e+00, -1.9677e+00,  0.0000e+00,  2.5637e-01,
#          -1.1854e+00,  4.1794e-01, -6.6121e-02,  2.6101e-01,  9.1824e-01,
#           8.7951e-02, -3.7541e-01,  0.0000e+00, -3.3461e-01,  0.0000e+00,
#          -8.2637e-01],
#         [ 0.0000e+00,  1.6156e+00,  2.2874e-01,  7.7311e-01,  1.4508e+00,
#          -0.0000e+00, -4.6499e-01,  0.0000e+00, -1.0626e+00, -5.5122e-02,
#           1.1872e+00, -1.5643e+00, -5.1581e-01,  1.3435e+00, -1.0720e+00,
#          -0.0000e+00],
#         [-1.1152e+00,  8.2459e-01,  2.3575e-01, -3.3181e-01, -0.0000e+00,
#           6.3949e-01, -4.0526e-01, -8.5891e-01, -1.0230e+00, -1.1834e+00,
#          -8.0167e-01,  0.0000e+00,  6.1047e-02, -1.3389e+00,  7.4813e-01,
# ...
